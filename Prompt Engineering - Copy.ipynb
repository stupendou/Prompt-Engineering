# %%
# !pip install openai
# Out:
# ...
#      ------------------------------------ 225.4/225.4 kB 982.5 kB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.1.1
#     Uninstalling typing_extensions-4.1.1:
#       Successfully uninstalled typing_extensions-4.1.1
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai
openai.api_key = "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"# MY OPENAI API KEY

# %%
# !pip3 install python-dotenv
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai
openai.api_key = "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"# MY OPENAI API KEY
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
import openai
openai.api_key = "sk-ulL#############################################"# MY OPENAI API KEY
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
client = openai.OpenAI(api_key=openai.api_key)
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
return response.choices[0].message.content

# %%
text = f"""
कुछ सुन्दर झीलों तथा कई भागों में घनी वृक्षदार सुन्दर घाटियों से युक्त एक समृद्ध प्राकृतिक विरासत है \

अलवर में राजस्थान के बहुत अच्छे वन्य जीव अभयारण्यों में से एक , सरिस्का , जो कि एक अत्यंत उत्कृष्ट बाघों का निवास स्थान है \

अलवर , अरावली पर्वत श्रेणी कि छोटी पहाड़ियों के झुंड़ों के बीच सुखपूर्वक बसा है \

राजपूत और मुगल शैली के स्थापत्य को समरसतापूर्वक मिलाता एक 18 वीं सदी का महल \

संग्रहालय की अन्य प्रदर्शित वस्तुओं में है भारतीय शस्त्रों का एक बहुमूल्य संग्रह \

सिटी पैलेस के पीछे महाराजा विनय सिंह द्वारा 1815 में निर्मित एक कृत्रिम झील है , जिसके किनारों पर कुछ मंदिर हैं \

इस प्रांत में स्थित है एक उल्लेखनीय बंगाली अंदरूनी छत व तोरणों वाली अद्भुत छतरी जिसे मूसी महारानी की छतरी के नाम से भी जाना जाता है\ 

1868 में महाराजा शिवदान सिंह के शासन काल में बनाये गये इस उद्यान में शिमला नामक मोहक वातावरण है जिसका निर्माण महाराजा मंगल सिंह द्वारा कराया गया और यहां की छावें इसे गर्मियों में एक काव्यात्मक पर्यटन स्थल बना देती हैं \

बंगाल की खाड़ी में भारत वर्ष के मध्य मार्ग में स्थित अंडमान तथा निकोबार द्वीप समूह में कभी अनेक जनजातिया रहती थीं जिन्होंने उनको सभ्य बनाने के किसी भी प्रयास का कड़ा प्रतिरोध किया \

भारतीय पौराणिक कथाएँ `अंडमान ’ नाम की खोज हन्दुमान या हनुमान , रामायण महाकाव्य के `मंकी गॉड ’ से करती हैं , जिनके लिए कहा जाता है कि उन्होंने राम की पत्नी देवी सीता को बचाने के लिए इन द्वीपों का प्रयोग सोपान के रूप में किया\ 

फिर , 1857 में प्रथम स्वतंत्रता संग्राम के पश्चात , अंग्रेजों ने इसे दंड देने का स्थान ( कर्नाटक , तमिलनाडु , महाराष्ट्र तथा उड़ीसा से भी\ 

बसर में स्थित देवी सरस्वती का मंदिर , दक्षिण भारत में इस देवी का एक और एकमात्र मंदिर है , तथा तीर्थयात्रा का एक प्रसिद्ध स्थान है \

वेमन समाधि , इस जिले में एक प्रसिद्ध पर्यटन स्थल है \

इस जिले की घटनाओं में से है इतिहास प्रसिद्ध पलनाडु युद्ध तथा 1921 का सर्वप्रथम कर ( टैक्स ) के खिलाफ असहयोग आंदोलन \

अदिलाबाद जिला पूर्व , पश्चिम तथा उत्तर दिशाओं में महाराष्ट्र राज्य से , दक्षिण दिशा में करीमनगर व निजामाबाद जिलों से घिरा हुआ है \

"""
prompt = f"""
Summarize the text delimited by triple backticks \
into two sentences
'''{text}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Input In [17], in <cell line: 38>()
#       1 text = f"""
#       2 कुछ सुन्दर झीलों तथा कई भागों में घनी वृक्षदार सुन्दर घाटियों से युक्त एक समृद्ध प्राकृतिक विरासत है \
#       3
#    (...)
#      31
#      32 """
#      33 prompt = f"""
#      34 Summarize the text delimited by triple backticks \
#      35 into two sentences
#      36 '''{text}'''
#      37 """
# ---> 38 response = get_completion(prompt)
#      39 print(response)
#
# Input In [16], in get_completion(prompt, model)
#       2 def get_completion(prompt, model="gpt-3.5-turbo"):
#       3     messages = [{"role": "user", "content": prompt}]
# ----> 4     response = client.chat.completions.create(
#       5         model=model,
#       6         messages=messages,
#       7         temperature=0
#       8     )
# ...

# %%
text = f"""
You should express what you want a model to do by \ 
providing instructions that are as clear and \ 
specific as you can possibly make them. \ 
This will guide the model towards the desired output, \ 
and reduce the chances of receiving irrelevant \ 
or incorrect responses. Don't confuse writing a \ 
clear prompt with writing a short prompt. \ 
In many cases, longer prompts provide more clarity \ 
and context for the model, which can lead to \ 
more detailed and relevant outputs.

"""
prompt = f"""
Summarize the text delimited by triple backticks \
into two sentences
'''{text}'''
"""
response = get_completion(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Input In [18], in <cell line: 19>()
#       1 text = f"""
#       2 You should express what you want a model to do by \
#       3 providing instructions that are as clear and \
#    (...)
#      12
#      13 """
#      14 prompt = f"""
#      15 Summarize the text delimited by triple backticks \
#      16 into two sentences
#      17 '''{text}'''
#      18 """
# ---> 19 response = get_completion(prompt)
#      20 print(response)
#
# Input In [16], in get_completion(prompt, model)
#       2 def get_completion(prompt, model="gpt-3.5-turbo"):
#       3     messages = [{"role": "user", "content": prompt}]
# ----> 4     response = client.chat.completions.create(
#       5         model=model,
#       6         messages=messages,
#       7         temperature=0
#       8     )
#       9     return response.choices[0].message.content
#
# ...

# %%
prompt = f"""
Generate a list of three made-up book titles along \ 
with their authors and genres. 
Provide them in JSON format with the following keys: 
book_id, title, author, genre.
"""
response = get_completion(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Input In [19], in <cell line: 7>()
#       1 prompt = f"""
#       2 Generate a list of three made-up book titles along \
#       3 with their authors and genres.
#       4 Provide them in JSON format with the following keys:
#       5 book_id, title, author, genre.
#       6 """
# ----> 7 response = get_completion(prompt)
#       8 print(response)
#
# Input In [16], in get_completion(prompt, model)
#       2 def get_completion(prompt, model="gpt-3.5-turbo"):
#       3     messages = [{"role": "user", "content": prompt}]
# ----> 4     response = client.chat.completions.create(
#       5         model=model,
#       6         messages=messages,
#       7         temperature=0
#       8     )
#       9     return response.choices[0].message.content
#
# ...

# %%
prompt = f"""
Generate a list of three books by J Sai Deepak titles along \ 
with their authors and genres. 
Provide them in JSON format with the following keys: 
book_id, title, author, genre.
"""
response = get_completion(prompt)
print(response)
# The prompt gave wrong two answers becasue the author has not authored three books

# %%
# COnditions satisfaction or not
text_1 = f"""
Making a cup of tea is easy! First, you need to get some \ 
water boiling. While that's happening, \ 
grab a cup and put a tea bag in it. Once the water is \ 
hot enough, just pour it over the tea bag. \ 
Let it sit for a bit so the tea can steep. After a \ 
few minutes, take out the tea bag. If you \ 
like, you can add some sugar or milk to taste. \ 
And that's it! You've got yourself a delicious \ 
cup of tea to enjoy.
"""
prompt = f"""
You will be provided with text delimited by triple quotes. 
If it contains a sequence of instructions, \ 
re-write those instructions in the following format:

Step 1 - ...
Step 2 - …
…
Step N - …

If the text does not contain a sequence of instructions, \ 
then simply write \"No steps provided.\"

\"\"\"{text_1}\"\"\"
"""
response = get_completion(prompt)
print("Completion for Text 1:")
print(response)

# %%
text_2 = f"""
The sun is shining brightly today, and the birds are \
singing. It's a beautiful day to go for a \ 
walk in the park. The flowers are blooming, and the \ 
trees are swaying gently in the breeze. People \ 
are out and about, enjoying the lovely weather. \ 
Some are having picnics, while others are playing \ 
games or simply relaxing on the grass. It's a \ 
perfect day to spend time outdoors and appreciate the \ 
beauty of nature.
"""
prompt = f"""
You will be provided with text delimited by triple quotes. 
If it contains a sequence of instructions, \ 
re-write those instructions in the following format:

Step 1 - ...
Step 2 - …
…
Step N - …

If the text does not contain a sequence of instructions, \ 
then simply write \"No steps provided.\"

\"\"\"{text_2}\"\"\"
"""
response = get_completion(prompt)
print("Completion for Text 2:")
print(response)

# %%
#few short prompting
prompt = f"""
Your task is to answer in a consistent style.

<child>: Teach me about patience.

<grandparent>: The river that carves the deepest \ 
valley flows from a modest spring; the \ 
grandest symphony originates from a single note; \ 
the most intricate tapestry begins with a solitary thread.

<child>: Teach me about resilience.
"""
response = get_completion(prompt)
print(response)

# %%
#LET THE MODEL TIME TO THINK
text = f"""
कुछ सुन्दर झीलों तथा कई भागों में घनी वृक्षदार सुन्दर घाटियों से युक्त एक समृद्ध प्राकृतिक विरासत है 

अलवर में राजस्थान के बहुत अच्छे वन्य जीव अभयारण्यों में से एक , सरिस्का , जो कि एक अत्यंत उत्कृष्ट बाघों का निवास स्थान है 

अलवर , अरावली पर्वत श्रेणी कि छोटी पहाड़ियों के झुंड़ों के बीच सुखपूर्वक बसा है 

राजपूत और मुगल शैली के स्थापत्य को समरसतापूर्वक मिलाता एक 18 वीं सदी का महल 

संग्रहालय की अन्य प्रदर्शित वस्तुओं में है भारतीय शस्त्रों का एक बहुमूल्य संग्रह 

सिटी पैलेस के पीछे महाराजा विनय सिंह द्वारा 1815 में निर्मित एक कृत्रिम झील है , जिसके किनारों पर कुछ मंदिर हैं 

इस प्रांत में स्थित है एक उल्लेखनीय बंगाली अंदरूनी छत व तोरणों वाली अद्भुत छतरी जिसे मूसी महारानी की छतरी के नाम से भी जाना जाता है 

1868 में महाराजा शिवदान सिंह के शासन काल में बनाये गये इस उद्यान में शिमला नामक मोहक वातावरण है जिसका निर्माण महाराजा मंगल सिंह द्वारा कराया गया और यहां की छावें इसे गर्मियों में एक काव्यात्मक पर्यटन स्थल बना देती हैं 

बंगाल की खाड़ी में भारत वर्ष के मध्य मार्ग में स्थित अंडमान तथा निकोबार द्वीप समूह में कभी अनेक जनजातिया रहती थीं जिन्होंने उनको सभ्य बनाने के किसी भी प्रयास का कड़ा प्रतिरोध किया 

भारतीय पौराणिक कथाएँ `अंडमान ’ नाम की खोज हन्दुमान या हनुमान , रामायण महाकाव्य के `मंकी गॉड ’ से करती हैं , जिनके लिए कहा जाता है कि उन्होंने राम की पत्नी देवी सीता को बचाने के लिए इन द्वीपों का प्रयोग सोपान के रूप में किया 

फिर , 1857 में प्रथम स्वतंत्रता संग्राम के पश्चात , अंग्रेजों ने इसे दंड देने का स्थान ( कर्नाटक , तमिलनाडु , महाराष्ट्र तथा उड़ीसा से भी 

बसर में स्थित देवी सरस्वती का मंदिर , दक्षिण भारत में इस देवी का एक और एकमात्र मंदिर है , तथा तीर्थयात्रा का एक प्रसिद्ध स्थान है 

वेमन समाधि , इस जिले में एक प्रसिद्ध पर्यटन स्थल है 
"""
prompt = f"""
Perform the following actions:
1- Summarize the text delimited by triple backticks \ 
into a single sentence.
2- Convert the summary into Hindi.
3-List each proper nouns in the Hindi Summary.
4- Output a json object that contains the following\
keys: Hindi_summary, proper_nouns

Separate your answers with line breaks

Text:
```{text}```
"""
response = get_completion(prompt)
print(response)

# %%
#OUTPUT IN A SPECIFIED FORMAT
prompt_2 = f"""
Your task is to perform the following actions: 
1 - Summarize the following text delimited by 
  <> with 1 sentence.
2 - Translate the summary into French.
3 - List each name in the French summary.
4 - Output a json object that contains
लौहगढ़ , लोहे के किले के नाम से भी जाना जाता है , लौहगढ़ भरतपुर के प्रमुख ऐतिहासिक आकर्षणों में से एक है \
भरतपुर संग्रहालय उस स्थान की शाही शान के साथ , दिन का प्रमुख स्रोत है \
एक सुंदर बगीचा , नेहरू पार्क, भरतपुर संग्रहालय के निकट स्थित हैं \
रंगबिरंगे फूलों और हरी घास के उद्यानों से भरा नेहरू पार्क अपनी उत्कृष्ट सुंदरता के साथ पर्यटकों को आकर्षित करता है \
डीग महल एक मजबूत औऱ विशाल किला है जो भरतपुर के शासकों के लिए ग्रीष्म सराय का काम करता था \
भरतपुर भ्रमण के लिए अक्टूबर , नवंबर और फरवरी से मार्च के महीने के दौरान का समय उत्तम है \
भरतपुर में एक स्थान से दूसरे स्थान तक जाने के लिए कोई परिवहन साधनों जैसे टैक्सी, साइकिल रिक्शे और स्वचालित रिक्शे को ले सकता है \
जोधपुर शहर, राजस्थान राज्य के पश्चिमी भाग के केन्द्र में स्थित, राज्य का दूसरा सबसे बडा शहर है और यह महलों , किलों और मंदिरों के लिए लोकप्रिय है़।\
यह पर्यटन स्थल घूमने के लिए अच्छा है \
शहर की अर्थव्यवस्था कई उद्योगों पर निर्भर करती है, जिनमें हस्तकला , टैक्सटाइल और कुछ धातुओं पर आधारित उद्योग हैं \
मरुस्थल के हृदय में स्थित राजस्थान का यह शहर, राजस्थान का शानदार , प्रभावशाली और अपरिवर्तनीय मुकुट है \
राव जोधा 1459 में कुल के मुखिया राठौरों के नाम से जाने जाते, पूर्वजों की भूमि बुलाये जाने वाले जोधपुर की नींव रखी \
मेहरानगढ का किला भारत के सबसे बडे किलों में से एक है जो एक 125 मी . पहाडी की चोटी पर स्थित है तथा 5 किमी के क्षेत्र में विस्तृत है \
मेहरानगढ किले के अन्दर कई सजे हुए स्थान जैसे मोतीमहल, कूल महल ,शीश महल स्थित हैं \
मेहरानगढ किले के अंदर का संग्रहालय भी सूक्ष्मचित्रों, संगीत यंत्रों , पोशाकों , आयुधों आदि का अच्छा संग्रह रखता है \
मेहरानगढ किले मे सात दरवाजे हैं जो शहर का आश्चर्यजनक दृश्य प्रदान करते हैं \
उम्मेद भवन लाल बालू पत्थर तथा संगमरमर से बना है और इसने महाराजा उम्मेदसिंह के निरीक्षण में बनने के लिेए 1929 - 1943 तक लगभग 16 वर्ष लिए \
जसवंत थंडा एक सफेद संगमरमर का मकबरा 1899 में महाराजा जसवंत सिंह द्वितीय की स्मृति मे बना था \
जसवंत थंडा में जोघपुर के शासकों के कुछ आलेख भी दिखाये गये हैं \
उम्म्द बाग के मध्य में स्थित सरकारी संग्रहालय , आयुधों , टैक्सटाइल कला , हस्तलिपियों , आलेखों स्थानीय कला व शिल्प का अच्छा संग्रह रखता है \
बालसंमंद झील तथा महल एक कृत्रिम झील है , यह एक विशाल पिकनिक स्थल है और यह 1159 ई . पू .  मे बना था \
अक्टूबर के महीने में महावर मुख्य पर्व मनाया जाता है \
अन्तःपुरों के नमूने में बनी अनर सागर हवेली एक पाच मंजिल ऊंची हवेली है जो सुंदर भित्तीचित्रों से सजी हुई है \
उदयपुर मेवाड के प्रारंभिक राज की राजधानी है , और अब उदयपुर जिले के प्रशासन का मुख्य केन्द्र है शहर झीलों और महलों का शहर है जो चारों तरफ हरी भरी अरावली श्रेणी तथा स्फटिक के समान स्वच्छ पानी की झीलों से घिरा है \
कल्पना और सुंदरता का आदर्श समन्वय उदयपुर चित्रकारों , कवियों और लेखकों की कल्पना के लिए प्रथम पसंद हो सकता है \
उदयपुर राजस्थान के दक्षिणि भाग में स्थित है और यह चारों तरफ अरावली श्रेणी से घिरा है \
उदयपुर सुंदर झीलों , संरचित महलों हरे भरे बगीचों के लिए जाना जाता है लेकिन इस स्थान का प्रमुख आकर्षण लेक पैलेस तथा सिटी पैलेस हैं \
सिटी पैलेस पिछोंला झील के किनारे पर स्थित है एक विशाल औऱ प्रेरक दुर्ग शीशे तथा कांच के काम का सहायता बनाया गया है \
अभिकल्प तथा कला का एक आदर्श समन्वय सिटी पैलेस तकनीक तथा स्थापत्य कला की उन्नती के लिए जाना जाता है \
सिटी पैलेस का एक भाग अब संग्रहालय में बदल दिया गया है , जो कला और संस्कृति के कुछ सबसे अच्छे नमूनों को प्रदर्शित करता है \
उदयपुर अनेक आकर्षणों के अतिरिक्त प्राकृतिक सुंदरता से धन्य है , इसकी सर्वश्रेष्ठ स्थापत्य कला तथा हस्तकला के लिए राजस्थान के प्रसिद्ध शहरों में से एक है \
जग मंदिर , फतेह प्रकाश पैलेस क्रिस्टल गैलरी औऱ शिल्पग्राम कुछ सबसे अच्छे स्मारक औऱ स्थल उदयपुर के आस पास स्थित है \
जग मंदिर  पिछोला झील में स्थित द्वीप महल जो महाराणा करन सिंह के द्वारा प्रिंस हुर्रम को बाहर निकलने के लिए बनवाया था \
जग मंदिर इसके सुंदर बगीचों , प्रांगण और नक्काशीदार स्लेटी व नीले पत्थरों से बनी छतरी के लिए भी जाना जाता है \
फतेह प्रकाश पैलेस विलासिता तथा रहने की शैली का एक आदर्श उदाहरण है जो उदयपुर को शाही आतिथ्य व संस्कृति का शहर कहलाता है \
शिल्पग्राम गाँव की संकल्पना पर थोडा सा आधुनिकता के प्रभाव के साथ बनाया गया है \
कला , संस्कृति0 औऱ उद्योगों का आदर्श शिल्पग्राम में उपस्थित है औऱ यह मुख्यतः इसके गहरे बादामी लाल रंग बालु की सामग्री से बने टेराकोटा कार्य के लिए जाना जाता है \
मेवाड पर्व उदयपुर के प्रमुख पर्वों में से एक है और यह हर साल अप्रैल के महीनों में होता है \
उदयपुर में खरीददारी करना हमेशा एक उमंग भरा अनुभव होता है और यह स्थानीय श्रमिकों द्वारा बनाये गये उच्चकोटि के हस्तकला के कार्य को दिखाता है \
उदयपुर के मुख्य बाजार पैलेस रोड , हाथी पोल , बडा बाजार , बापू बाजार और चेतक सर्किल हैं , राजस्थली राजस्थान सरकार द्वारा स्वीकृत ऐम्पोरियम है \
सितंबर से मार्च तक का मौसम उदयपुर भ्रमण के लिए सबसे अच्छा है \
शाही शहर बीकानेर अनंत आकर्षण रखता है जैसा और कोई नहीं रखता है \
राजस्थान का मरुस्थलीय शहर इसके आकर्षणों जिनमें किले , मंदिर औऱ ऊंट पर्व सम्मिलित हैं के लिए प्रसिद्ध है ऊंटों के देश के नाम से जाना जाने वाला बीकानेर औद्योगिक क्षेत्र में भी पहचान बनाता है \
संसार में सबसे ज्यादा जाना जाता है इसकी बीकानेरी मिठाइयों और स्नैक्स के लिए , बीकानेर पर्यटन उद्योग को विकसित करता है यह राजस्थान की अर्थव्यवस्था में महत्वपूर्ण भूमिका निभाता है\ 
बीकानेर रोमांचक ऊंट की सवारी देखने के लिए प्रमुख केन्द्र है जो भीतरी राजस्थान की शानदार रहन_सहन का दृश्य देता है \
जूनागढ किले के अंदर एक संग्रहालय है जो बहुमूल्य अनोखी वस्तुओं का संग्रह रखता है \
लालगढ महल महाराजा गंगा सिंह के द्वारा बनवाया गया था और बीकानेर शहर के 3 किमी उत्तर में स्थित है \
राजस्थान पर्यटन विकास निगम ने लालगढ पैलेस के एक भाग को होटल में तब्दील कर दिया है \
लालगढ पैलेस के अंदर एक पुस्तकालय भी है जिसमें संस्कृत की हस्तलिपियों का विशाल संग्रह है \
गजनेर वन्यजीव अभ्यारण्य बीकानेर नगर से 32 किमी . दूर है तथा यह जानवरों तथा पक्षियों की कई प्रजातियों का घर है \
बन्देश्वर और सन्देश्वर मन्दिर दो भाइयों के द्वारा बनवाया गया था जैन तीर्थंकर पार्श्वनाथ को समर्पित है \
शीशे का कार्य तथा स्वर्ण पत्ती कला बन्देश्वर और सन्देश्वर मन्दिर के प्रमुख आकर्षण हैं \
गंगा गोल्डन जुबली संग्रहालय मिट्टी के बर्तनों , गलीचों , सिक्कों और आयुधों का विशाल संग्रह रखता है \
ऊंट पर्व हर साल जनवरी महीने में मनाया जाता है औऱ राजस्थान पर्यटन कला और संस्कृती विभाग , द्वारा आयोजित होता है \
प्रसिद्ध बीकानेरी भुजिया तथा मिठाइयां बीकानेर से खरीददारी के लिए सबसे अच्छी वस्तुएं हैं \
अक्तूबर से मार्च तक का समय शहर घूमने के लिए सबसे अच्छा है \
माउण्ट आबू ही राजस्थान का एक मात्र पवर्तीय स्थल है जो अरावली श्रेणी की दक्षिणी चोटी पर स्थित है \
ब्रिटिश काल के दौरान माउण्ट आबू ब्रिटिशों का गर्मियों का पसंदीदा स्थल बना \
गोमुख मन्दिर भगवान राम को समर्पित है , यह छोटा सा मन्दिर माउण्ट आबू से 4 किमी दक्षिण में स्थित है और इसका नाम एक संगमरमर के बने गाय मुख से निकलने वाली प्राकृतिक धारा को बहने से पडा \
नक्की झील कस्बे के केन्द्र में स्थित कृत्रिम झील है और यह सुंदर पहाडियों सुंदर पार्कों के द्वारा चारों तरफ से घिरा है और एक दर्शनीय स्थल है 

"""
text = f"""
जयपुर , भारत वर्ष के राजस्थान राज्य की राजधानी है|\
यह शहर गुलाबी नगर के नाम से लोकप्रिय  है |\
यह शहर ऐश्वर्यपूर्ण किलों , महलों और सुंदर झीलों के लिए प्रसिद्ध है , जो कि समस्त विश्व से पर्यटकों को आकर्षित करता है\ 
सिटी पैलेस महाराजा जयसिंह द्वितीय के द्वारा बनवाया गया था और यह एक मुगल और राजस्थानी स्थापत्य कला का मिश्रण है \
महाराजा सवाई प्रताप सिंह ने ईसी पश्चात 1799 में हवामहल बनवाया था और लाल उस्ताद शिल्पकार था \
आमेर किले के क्षेत्र में कई अन्तःपुर महलों के साथ , सभा स्थलों हॉल सीढीदार रास्तों , स्तंभों गुंबदों , बगीचे हैं \
"""
prompt_1 = f"""
Perform the following actions: 
1 - For each sentence delimited by \ list nouns in the sentence 
2 - Output a json object that contains the following \
keys: sentence , nouns.
Use the following format:
sentence: <sentence to find nouns>
antecedent: <list of nouns in sentence>
Output JSON: <json with sentence and antecedent>

Separate your answers with line breaks.

Text:
```{text}```
"""
response = get_completion(prompt)
print(response)

# %%
text=f"""
जयपुर , भारत वर्ष के राजस्थान राज्य की राजधानी है\
यह शहर गुलाबी नगर के नाम से लोकप्रिय  है \
यह शहर ऐश्वर्यपूर्ण किलों , महलों और सुंदर झीलों के लिए प्रसिद्ध है , जो कि समस्त विश्व से पर्यटकों को आकर्षित करता है\ 
सिटी पैलेस महाराजा जयसिंह द्वितीय के द्वारा बनवाया गया था और यह एक मुगल और राजस्थानी स्थापत्य कला का मिश्रण है \
महाराजा सवाई प्रताप सिंह ने ईसी पश्चात 1799 में हवामहल बनवाया था और लाल उस्ताद शिल्पकार था \
आमेर किले के क्षेत्र में कई अन्तःपुर महलों के साथ , सभा स्थलों हॉल सीढीदार रास्तों , स्तंभों गुंबदों , बगीचे हैं \
आमेर महल मुगल व हिन्दू स्थापत्य कला का अत्युत्तम उदाहरण है  \
"""
prompt = f"""
you will be provided with text delimited by triple quotes.
it contains sentences each in new line
For each sentence 
Perform the following actions:
1-List each proper nouns in the Hindi Sentence.
2- Output a json object that contains the following\
keys: Hindi_sentence, proper_nouns
Use the following format:
sentence: <sentence to find nouns>
mentions: <list of nouns in sentence>
Output JSON: <json with sentence and mentions>
Separate your answers with line breaks.
Text:
```{text}```
"""
response = get_completion(prompt)
print(response)

# %%
text= """
यह देश विश्व के उच्चतम झरनों का ग्रह है , एंजल फॉल (लगभग नियागत फॉल से 16 गुणा ऊँचा) और विश्व की सबसे लंबी व ऊँची केबल कार , मेरिडा शहर के विश्वविद्यालयों से यात्रियों को 4765 मीटर (15, 629 फीट) ऊँची पिको एस्पेजो पर खींच कर ले आती है 
राजधानी, काराकास, प्रतिष्ठित अच्छे ऐतिहासिक मकबरे , म्यूजियम व कला दीर्घा , नए व पुराने स्थापत्य के विषम उदाहरणों का श्रेष्ठ संग्रह है 
इसcataphoric देश के दर्शकों पास आरामदायक सरायों का अनुभव, सांस्कृतिक शहर में विराम या साहसिक क्रिया-कलापों की सम्पत्ति का विकल्प है 
अगर वोC एक या उपरोक्त सभी को अनुभव करना चाहते हैं तो वेनेजुएला के पास प्रस्तुत करने के लिए  काफी है 
लगभग 500 साल पहले, स्पेनिश साहसों का प्रभाव, पर्वतों के ताज लंबे सुन्दर चर्च, मैक्सिको शहर के चौक, व बड़े राज्यों के सफेद पुते दीवारों में देखा जा सकता है 
परन्तु पालेंक्यु व टियोटियुकान में अनूठे मंदिरों और पिरामिडों में और देशी संस्कृति की दर्जनों परंपराओं में पूर्व निवासियों की स्मृतियॉँ शेष हैं 
मैक्सिको के प्रसिद्ध गूढ़ मसालेदार खाद्यपदार्थ, केक व एनकिलेडा, इनC सबको एक साथ , तेज लाल शराब व नशीली मदिरा व मेसकल के साथ लिया जाता है 
मैक्सिको की सबसे पुरानी जानी गई सभ्यता, ईसा से दो सदी पहले की होलमिक थी, एक म्यान संस्कृति जोC धर्म स्थापत्य , व गणित में उन्नत थी जो 600 - 900  ईसा सन् मे चरमोत्कर्ष पर पहुँची थी 
टोलटेक्स इसC समय की प्रधान सभ्यता थी 
वेC प्रसिद्ध एजटेक्स के पूर्वज थे, उत्तम शिल्प, शिष्ट वाणी और मानसिक खोज के लिए जाने जाते हैं 
सन् 1519 में हरनान केट्सि नामक स्पेनियार्ड क्युबा से 550 लोगों की शक्तिशाली भीड़ के साथ आया 
एजटेक सम्राट ने युकाटन पेनिनसुला से पैसिफिक तक की विशाल भूमि, 370 स्वतंत्र राज्यों के साथ अपने अधिकारों के नियंत्रण में कर ली 
अपने राजधानी नगर , तेनाचतितलेन से शासन करते हुए , एजटेक्स अपनी प्रजा से भारी कर माँगते थे , जिसके कारण कुछ र्कोट्स की तरफ हो गए 
कोर्टेज की तरफ दूसरा कारण एक भाग्यशाली घटना थी , पौराणिक कथाओं के अनुसार 1519 ही वह वर्ष था , जब एजटेक भगवान , क्वेटजालकोटल , पूर्व से लौटेगा और इसलिए कोर्टस को गलती से भगवान मान लिया गया 
दो साल के युद्ध के बाद , एजटेक्स हरा दिए गए 
मैक्सिको ने 1810 - 21 के युद्ध के बाद स्वाधीनता हासिल की


"""
prompt = f"""
you will be provided with text delimited by triple quotes.
it contains sentences each in new line
For each sentence 
Perform the following actions:
1-List each  nouns in the Hindi Sentence.
Use the following format:
sentence: <sentence to find nouns>
mentions: <list of nouns in sentence>
Output JSON: <json with sentence and mentions>

Separate your answers with line breaks.
Text:
```{text}```
"""
response = get_completion(prompt)
print(response)

# %%
#SUMMARIZATION

# %%
# 08-06-2024
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"): # Andrew mentioned that the prompt/ completion paradigm is preferable for this class
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
prod_review = """
Got this panda plush toy for my daughter's birthday, \
who loves it and takes it everywhere. It's soft and \ 
super cute, and its face has a friendly look. It's \ 
a bit small for what I paid though. I think there \ 
might be other options that are bigger for the \ 
same price. It arrived a day earlier than expected, \ 
so I got to play with it myself before I gave it \ 
to her.
"""

prompt = f"""
Your task is to generate a short summary of a product \
review from an ecommerce site. 

Summarize the review below, delimited by triple 
backticks, in at most 2 sentences. 

Review: ```{prod_review}```
"""

response = get_completion(prompt)
print(response)

# %%
OUTPUT OBTAINED: ATmost 2 sentences
The panda plush toy is soft, cute, and loved by the reviewer's daughter. 
However, the reviewer feels it is a bit small for the price paid and suggests
there may be larger options available for the same price.

We found that CHATGPT 3.5 Turbo automatically resolved

# %%
OUTPUT OBTAINED: ATMOST 1 SENTENCES
The panda plush toy is soft, cute, and loved by the reviewer's daughter, 
but they feel it is a bit small for the price paid.

# %%
#Coversational interface via large language model
#OBSERVATION 1: NO DEFINED CRITERIA FOR SUMMARIZATION SO IS
#EXPECTED To work on Sentence salience in terms of order of occurence in document seems so

#OBSERVATION 2: The summarization could resolve AR intersentential as well as intra sentential in summary 

#OBSERVATION 3 : CHATGPT PERFORMED MIX OF ABSTRACTIVE SUMMARIZATION
#OBSERVATION: HINDI INPUT OUTPUT IN ENGLISH passive voice conversipn from active
#OBSERVATION: ITERATIVE RUNNING OVER SAME PROMPT DID ENHANCE THE GENERATED HEADLINE
#CHATGPT IS UNIVERSAL TRANSFORMTAOR, help in spell check and grammar check,
#OBSERVATION: Each conversation with a language model is a stanalone interaction thus means that we need to provide
#             all relevant information to perform a task from the current conversation.
#OBSERVATION: Capabilities of a LLM is summarizing, infering, transforming and Expanding
#Hallucination is a problem

# %%
pprompt = f"""
Your task is to 
Your task is to perform the following actions: 
1 - generate summary of the given text
delimited by triple backticks in atmost 5 sentences
2 - Translate the summary into Hindi.

Use the following format:
Text: <text to summarize>
Summary: <summary>
Translation: <summary translation>

Review: ```{text}```
"""

response = get_completion(prompt)
print(response)

# %%
Your task is to answer in consistent style
Consider the below examples like which your answer should be approached: 

<sentence>: राजेन्द माथुर उन पत्रकारों की पहली पंक्ति में थे 
जिन्होंने आजादी के बाद हिंदी पत्रकारिता को आधुनिक बनाया।   

<Particpating entities> : < राजेन्द माथुर, आजादी , हिंदी पत्रकारिता>
<anaphora> : < उन , जिन्होंने >

<sentence> :उनकी आधुनिकता   पश्चिमी मूल्यों   पर आधारित
आधुनिकता नहीं थी  जिसमें काफी हद तक   इतिहास का निषेध 
है। 

<participating entities>: <आधुनिकता , पश्चिमी मूल्यों , इतिहास >
<anaphora> : < उनकी ,जिसमें >

# %%
# 
prompt = f"""
You will be provided with text delimited by triple quotes.P
Perform the following actions on text: 
1- For each sentence delimited by | list proper nouns and  
demonstrative pronouns, relative pronouns,
reflexive pronoun, locative pronoun in the sentence and make sure to
consider multi word nouns together. 
2- Output a json object that contains the following\
keys: Hindi_sentence, nouns, Pronouns 
Use the following format:
sentence: <sentence to find nouns>
proper_nouns: <list of nouns in sentence>
Pronouns : <list of Pronouns in sentence>

After performing the above task Summarize the text delimited by triple 
backticks in Hindi
Review: ```{text}```
"""

response = get_completion(prompt)
print(response)

# %%
text = """पुस्तक में   राजेन्द्र सहगल   के 30 व्यंग्य   संकलित हैं।  
सामाजिक और   राजनीतिक   विसंगतियों पर   व्यंग्य करने   वाले इन व्यंग्य   लेखों में आज के   समय पर तल्ख   टिप्पणियां की गई   हैं।
राजेन्द्र   सहगल किसी भी एक   विडंबनापूर्ण   जीवन स्थिति को   चुनते हैं और उससे   जुड़े तमाम   प्रसंगों को   व्यग्यांत्मक   लहजे में बयान   करते हैं। 
रोजमर्रा की   जिंदगी से जुड़े   इन व्यंग्य लेखों   की रोचकता उसका   सबसे बड़ा गुण है। 
हालांकि हिंदी   में व्यग्यकारों   की नई पीढ़ी   परसाई-शरद जोशी और   रवीन्दनाथ   त्यागी के दौर से   आगे बढ़ने में अभी   सफलता नहीं पा सकी   है। 
अब भी ये   त्रयी शिखर की तरह   सामने हैं। 
आज के   व्यंग्य लेखकों   की उपलब्धि तभी   रेखांकित होगी जब   वे इस त्रयी से   आगे जाएंगे।     """

# %%
#Summary generation
#Summary generation
prompt = f"""
Your task is to 
Your task is to perform the following actions: 
1 - generate summary of the given text
delimited by triple backticks in 2 of sentences and make sure you do not
copy the content from original text you are
summarizing
2 - Translate the summary into Hindi.

Use the following format:
Text: <text to summarize>
Summary: <summary>
Translation: <summary translation>

Review: ```{text}```
"""

response = get_completion(prompt)
print(response)

# %%
#PARTICIPATING ENTITIES
prompt = f"""
You will be provided with text delimited by triple backticks
Perform the following actions on text: 
1- For each sentence delimited by | list proper nouns and  
demonstrative pronouns, relative pronouns,
reflexive pronoun, locative pronoun in the sentence 
2- Output a json object that contains the following\
keys: Hindi_sentence, nouns, Pronouns 
Use the following format:
sentence: <sentence to find nouns>
proper_nouns: <list of nouns in sentence>
Pronouns : <list of Pronouns in sentence>
Review: ```{text}```
"""

response = get_completion(prompt)

# %%
#HEADLINE GENERATION
prompt = f"""
Your task is to generate a headline in atmost 8 words 
for the given news text delimited by triple backticks
Translate the headline in Hindi

Text: ```{text}```
"""

response = get_completion(prompt)
print(response)

# %%
# Headline as summarizer:
prompt = f"""
generate summary of the given text
delimited by triple backticks in  8 words.

Translate the summary in Hindi
Text: ```{text}```
"""

response = get_completion(prompt)
print(response)

# %%
#HEADLINE AS SUMMARIZER:WITH SPECIAL FOCUS
prompt = f"""
Your task is to generate a headline in atmost 8 words 
for the given news text delimited by triple backticks with focus on
events and entity
Translate the headline in Hindi

Text: ```{text}```
"""

response = get_completion(prompt)
print(response)

# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"): # Andrew mentioned that the prompt/ completion paradigm is preferable for this class
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
text_1=""" नगालैंड में   दीमापुर के नजदीक   शुक्रवार को   नेशनल सोशलिस्ट   कौंसिल ऑफ   नगालैंड   (एनएससीएन) के   खपलांग और इसाक   मुईवा गुट के बीच   संघर्ष में   खपलांग गुट के कम   से कम छह विद्रोही   मारे गए। केंद   सरकार और   एनएससीएन में हुए   संघर्षविराम के   बाद दोनों विरोधी   गुटों के बीच यह   पहला बड़ा संघर्ष   है।   पुलिस सूत्रों ने   शनिवार को बताया   कि खपलांग गुट के   लोगों के गोलियों   से छलनी शव   शुक्रवार को   तेयाईफे गांव के   धान के खेतों में   पाए गए। पुलिस को   इस संबंध में   गांववालों ने   सूचित किया था।   खपलांग गुट ने एक   बयान में इस   कार्रवाई को   कायरतापूर्ण   बताते हुए कहा कि   इस जघन्य अपराध को   सहन नहीं किया   जाएगा। इस   कार्रवाई से साफ   पता चलता है कि   इसाक मुईवा गुट   नगा समाज को छिन्न   भिन्न करना चाहता   है। खपलांग गुट ने   क्रिसमस पर्व से   पहले इसाक मुईवा   गुट से   संघर्षविराम का   प्रस्ताव भी रखा   था।   इसाक मुईवा गुट ने   भी बयान जारी कर   इस कार्रवाई को   दुर्भाग्यपूर्ण   बताया है। बयान   में कहा गया कि   नगा समाज की शीर्ष   संस्था होहो   द्वारा शांति   प्रक्रिया शुरू   करने के बाद यह   दुर्भाग्यपूर्ण   है। एनएससीएन के   दोनों गुट केंद   सरकार के साथ किए   गए संघर्षविराम   समझौते से सहमत   थे। नगा होहो ने   भी दोनों गुटों से   शांति प्रक्रिया   का सकारात्मक   जवाब देने की अपील   की और   संघर्षविराम मंे   सहयोग करने के लिए   कहा है। """
text_2=""" दिल्ली के   व्यापारियों के   संगठन ने नगर निगम   से माँग की है कि   बाहर के राज्यों   से आने वाले   वाहनों से वसूले   जा रहे टोल-टैक्स   को समाप्त किया   जाए। उनकी यह माँग   भी है कि गोदामों   के लिए निगम के   स्वास्थ्य विभाग   द्वारा जारी किए   जा रहे ' एडहॉक '   लाइसेंसों को   बनाने की अंतिम   तिथि 31 मार्च 2002 तक   बढ़ाई जाए।   महापौर और   निगमायुक्त को   पत्र लिखकर   व्यापारी वर्ग की   माँगों पर ध्यान   देने की अनुरोध भी   किया गया है।   दिल्ली ट्रेड   एसोसिएशन के   अध्यक्ष विजय   गुप्ता ने अरोप   लगाया है कि   टोल-टैक्स के कारण   दिल्ली में   प्रवेश करते ही   मालवाहक वाहनों   को भारी   भ्रष्टाचार का   सामना करना पड़ता   है। यही हाल   दुकानों और   गोदामों के   लाइसेंस बनाए   जाने की   प्रक्रिया में भी   चल रहा है। जिन   दुकानदारों ने   वर्षों पहले   लाइसेंस के लिए   आवेदन किए थे ,   उनके लाइसेंस भी   नहीं बन सके हैं। """
text_6= """चीन ने   आखिर अपने   स्वदेशी तकनीक से   क्लोन बछिया को   अवतरित करा ही   लिया। पूर्वी चीन   के शंदोंग प्रांत   की राजधानी जिनान   में यह बछिया पैदा   हुई। एक रिपोर्ट   के अनुसार काले और   सफेद रंगों वाली   यह बछिया   शुक्रवार को   जन्मी। इसे '   वेईवेई ' नाम दिया   गया है और वह बोतल   से दूध पी रही है।   सिन्हुआ समाचार   एजेंसी ने यह   जानकारी दी।   चीनी विज्ञान   अकादमी के तहत   प्राणी अनुसंधान   संस्थान के   शोधार्थी चेन   दयुआन ने कहा कि   देश में ही गर्भ   निर्माण और   प्रत्यारोपण   तकनीक के कारण   क्लोन बछिया का   जन्म संभव हो   पाया। इससे पहले   देश में गायों का   क्लोन तैयार किया   गया था , लेकिन   गर्भ दूसरे देशों   से मंगाए गए थे।"""
text=[text_1,text_2,text_3,text_4,text_5,text_6]

# %%
### THE FOLLOWING FOUR CELL CAN BE USED FOR MULTI CCLASS DEPRESSION DETECION DATASET.
for i in range(len(text)):
    prompt = f"""
Your task is to generate a headline in atmost 8 words 
for the given news text delimited by triple backticks
Translate the headline in Hindi

Text: ```{text[i]}```
"""

response = get_completion(prompt)
print(i, response, "\n")

# %%
text="it’s okay to cry ### After 8 months of break up and 4 months of no contact, I finally cried for the first time. It was a strange kind of cry.... a cry that I knew I had no emotions and I do not want her back in my life (even after she dumped me through an email). To all that are going through a break up... you will have relapses and will go through different stages of break up... stay strong, be kind to yourself, speak to love ones and remember guys... it’s okay to cry."

# %%
prompt= f"""
Remove unnecessary symbols like hash, multiple dots\
and punatuations from the text \
delimited by triple backticks and generate the \
new output

Text:'''{text}'''
"""
response = get_completion(prompt)
print(response)

# %%
topic_list=["sadeness","hopelessness","depression","anger","love","positive"]

# %%
prompt =f"""
Given the text delimited by triple backticks\
can you list different form of emotions \
the text contains and decide finally\
whether the review is a depressed one or not.
List the answers as a list with 0 and 1 for each feeling.\
list of topics={",".join(topic_list)}
text: '''{text}'''
"""
response = get_completion(prompt)
print(response)

# %%
ChatGPT supports translation for over 50 languages, including but not limited to English, Spanish, French, German, Chinese, Japanese, Korean, Arabic, Russian, and many more.

# %%
user_messages = [
  "La performance du système est plus lente que d'habitude.",  # System performance is slower than normal         
  "Mi monitor tiene píxeles que no se iluminan.",              # My monitor has pixels that are not lighting
  "Il mio mouse non funziona",                                 # My mouse is not working
  "Mój klawisz Ctrl jest zepsuty",                             # My keyboard has a broken control key
  "我的屏幕在闪烁"                                               # My screen is flashing
]

# %%
or issue in user_messages:
    prompt = f"Tell me what language this is: ```{issue}```"
    lang = get_completion(prompt)
    print(f"Original message ({lang}): {issue}")

    prompt = f"""
    Translate the following  text to English \
    and Korean: ```{issue}```
    """
    response = get_completion(prompt)
    print(response, "\n")

# %%
#PROOFREADING
text = f"""
Got this for my daughter for her birthday cuz she keeps taking \
mine from my room.  Yes, adults also like pandas too.  She takes \
it everywhere with her, and it's super soft and cute.  One of the \
ears is a bit lower than the other, and I don't think that was \
designed to be asymmetrical. It's a bit small for what I paid for it \
though. I think there might be other options that are bigger for \
the same price.  It arrived a day earlier than expected, so I got \
to play with it myself before I gave it to my daughter.
"""
prompt = f"proofread and correct this review: ```{text}```"
response = get_completion(prompt)
print(response)

# %%
#ORDER CHATBOT
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for a pizza restaurant. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  12.95, 10.00, 7.00 \
cheese pizza   10.95, 9.25, 6.50 \
eggplant pizza   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
